# %% [markdown]
# <a href="https://colab.research.google.com/github/rameshpolaveni2576/python-basics-assignment/blob/main/movie_tickets_booking_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
total_tickets=350
remaining_seats=total_tickets
tickets_sold=0
rejected_bookings=0
while remaining_seats>0:
  user_input=int(input("Enter the no of Tickets required? or 0 to exit: "))
  if user_input==0:
    print(f"Final Report is here:\nTotal tickets sold: {tickets_sold}\nrejeted bookings: {rejected_bookings}\nRemaining seats: {remaining_seats}")
    break
  if 1<user_input>15:
    print("---Invalid Booking Please enter valid no of tickets between 1-15:---")
  else:
    valid_booking=True
    for i in range(user_input):
      user_age=int(input(f"Please enter the age of person {i+1}: "))
      if user_age<12:
        valid_booking=False
        break
    if valid_booking:
      print(f"BOOKING CONFIRMED - {user_input} tickets 😊")
      tickets_sold=tickets_sold+user_input
      remaining_seats=remaining_seats-user_input
      print(f"Tickets Sold: {tickets_sold}\nRemaining seats available to book: {remaining_seats}\nRejected Bookings: {rejected_bookings}")
    else:
      print("BOOKING REJECTED - Age restriction for one more persons")
      rejected_bookings=rejected_bookings+1
if remaining_seats==0:
  print("----House Full-----")
# Out:
# Enter the no of Tickets required? or 0 to exit: 3
# Please enter the age of person 1: 15
# Please enter the age of person 2: 15
# Please enter the age of person 3: 25
# BOOKING CONFIRMED - 3 tickets 😊
# Tickets Sold: 3
# Remaining seats available to book: 347
# Rejected Bookings: 0
# Enter the no of Tickets required? or 0 to exit: 2
# Please enter the age of person 1: 26
# Please enter the age of person 2: 29
# BOOKING CONFIRMED - 2 tickets 😊
# Tickets Sold: 5
# Remaining seats available to book: 345
# Rejected Bookings: 0
# Enter the no of Tickets required? or 0 to exit: 0
# Final Report is here:
# Total tickets sold: 5
# rejeted bookings: 0
# Remaining seats: 345
